# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting streamlit
#   Downloading streamlit-1.13.0-py2.py3-none-any.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 59.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 2)) (1.2.5)
# Requirement already satisfied: numpy in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 3)) (1.23.3)
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 KB 24.0 MB/s eta 0:00:00
# Collecting openpyxl
#   Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 KB 45.5 MB/s eta 0:00:00
# Collecting XlsxWriter
#   Downloading XlsxWriter-3.0.3-py3-none-any.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.0/150.0 KB 37.5 MB/s eta 0:00:00
# Collecting bytesbufio
#   Downloading bytesbufio-1.0.3-py3-none-any.whl (3.8 kB)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.5/182.5 KB 46.9 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (9.2.0)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 KB 36.4 MB/s eta 0:00:00
# Requirement already satisfied: tzlocal>=1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (4.2)
# Requirement already satisfied: pyarrow>=4.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (9.0.0)
# Requirement already satisfied: tornado>=5.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (6.2)
# Collecting watchdog
#   Downloading watchdog-2.1.9-py3-none-manylinux2014_x86_64.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 KB 22.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (4.3.0)
# Requirement already satisfied: python-dateutil in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (2.8.2)
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting blinker>=1.0.0
#   Downloading blinker-1.5-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: protobuf!=3.20.2,<4,>=3.12 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (3.19.4)
# Requirement already satisfied: requests>=2.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (2.28.1)
# Requirement already satisfied: importlib-metadata>=1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (4.12.0)
# Requirement already satisfied: click>=7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (8.1.3)
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting semver
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: packaging>=14.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: cachetools>=4.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (5.2.0)
# Collecting rich>=10.11.0
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.5/237.5 KB 38.4 MB/s eta 0:00:00
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.0b4-py2.py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 125.7 MB/s eta 0:00:00
# Requirement already satisfied: altair>=3.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 1)) (4.2.0)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas->-r ./requirements.txt (line 2)) (2022.2.1)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: jsonschema>=3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair>=3.2.0->streamlit->-r ./requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: toolz in /shared-libs/python3.9/py/lib/python3.9/site-packages (from altair>=3.2.0->streamlit->-r ./requirements.txt (line 1)) (0.12.0)
# Requirement already satisfied: jinja2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair>=3.2.0->streamlit->-r ./requirements.txt (line 1)) (2.11.3)
# Requirement already satisfied: entrypoints in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair>=3.2.0->streamlit->-r ./requirements.txt (line 1)) (0.4)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 KB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from importlib-metadata>=1.4->streamlit->-r ./requirements.txt (line 1)) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging>=14.1->streamlit->-r ./requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil->streamlit->-r ./requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.4->streamlit->-r ./requirements.txt (line 1)) (2022.6.15.1)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.4->streamlit->-r ./requirements.txt (line 1)) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.4->streamlit->-r ./requirements.txt (line 1)) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.4->streamlit->-r ./requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from rich>=10.11.0->streamlit->-r ./requirements.txt (line 1)) (2.13.0)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 KB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: pytz-deprecation-shim in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tzlocal>=1.1->streamlit->-r ./requirements.txt (line 1)) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from validators>=0.2->streamlit->-r ./requirements.txt (line 1)) (5.1.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2->altair>=3.2.0->streamlit->-r ./requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: attrs>=17.4.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit->-r ./requirements.txt (line 1)) (22.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit->-r ./requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit->-r ./requirements.txt (line 1)) (58.1.0)
# Requirement already satisfied: tzdata in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit->-r ./requirements.txt (line 1)) (2022.2)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py): started
#   Building wheel for validators (setup.py): finished with status 'done'
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19582 sha256=557b8e573cb5e60e380a6d668ebe39b3d3771c6b0f82c6a73c23baa54319a945
#   Stored in directory: /root/.cache/pip/wheels/2d/f0/a8/1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
# Successfully built validators
# Installing collected packages: commonmark, XlsxWriter, xlrd, watchdog, validators, toml, smmap, semver, rich, pympler, et-xmlfile, bytesbufio, blinker, pydeck, openpyxl, gitdb, gitpython, streamlit
# Successfully installed XlsxWriter-3.0.3 blinker-1.5 bytesbufio-1.0.3 commonmark-0.9.1 et-xmlfile-1.1.0 gitdb-4.0.9 gitpython-3.1.29 openpyxl-3.0.10 pydeck-0.8.0b4 pympler-1.0.1 rich-12.6.0 semver-2.13.0 smmap-5.0.0 streamlit-1.13.0 toml-0.10.2 validators-0.20.0 watchdog-2.1.9 xlrd-2.0.1
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7d7b366a-7409-465b-adc7-aba3b485481f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
